# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# Load the dataset
data_file = Path("../data/MNCAATourneyDetailedResults.csv")
df = pd.read_csv(data_file)
df.head()
# Out:
#    Season  DayNum  WTeamID  WScore  LTeamID  LScore WLoc  NumOT  WFGM  WFGA  \
# 0    2003     134     1421      92     1411      84    N      1    32    69
# 1    2003     136     1112      80     1436      51    N      0    31    66
# 2    2003     136     1113      84     1272      71    N      0    31    59
# 3    2003     136     1141      79     1166      73    N      0    29    53
# 4    2003     136     1143      76     1301      74    N      1    27    64
#
#    ...  LFGA3  LFTM  LFTA  LOR  LDR  LAst  LTO  LStl  LBlk  LPF
# 0  ...     31    14    31   17   28    16   15     5     0   22
# 1  ...     16     7     7    8   26    12   17    10     3   15
# 2  ...     28    14    21   20   22    11   12     2     5   18
# 3  ...     17    12    17   14   17    20   21     6     6   21
# 4  ...     21    15    20   10   26    16   14     5     8   19
#
# [5 rows x 34 columns]

# %%
df.describe()
# Out:
#             Season       DayNum      WTeamID       WScore      LTeamID  \
# count  1449.000000  1449.000000  1449.000000  1449.000000  1449.000000
# mean   2013.841960   139.080745  1287.476190    75.648723  1292.518979
# std       6.639431     4.232989   103.285514    10.757312   105.991705
# min    2003.000000   134.000000  1101.000000    47.000000  1101.000000
# 25%    2008.000000   136.000000  1207.000000    68.000000  1209.000000
# 50%    2014.000000   137.000000  1276.000000    75.000000  1291.000000
# 75%    2019.000000   139.000000  1389.000000    83.000000  1392.000000
# max    2025.000000   154.000000  1463.000000   121.000000  1471.000000
#
#             LScore        NumOT         WFGM         WFGA        WFGM3  ...  \
# count  1449.000000  1449.000000  1449.000000  1449.000000  1449.000000  ...
# mean     63.908903     0.064182    26.569358    55.981366     7.190476  ...
# std      10.380668     0.279392     4.737391     7.227484     3.065067  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1449 entries, 0 to 1448
# Data columns (total 34 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Season   1449 non-null   int64
#  1   DayNum   1449 non-null   int64
#  2   WTeamID  1449 non-null   int64
#  3   WScore   1449 non-null   int64
#  4   LTeamID  1449 non-null   int64
#  5   LScore   1449 non-null   int64
#  6   WLoc     1449 non-null   str
#  7   NumOT    1449 non-null   int64
#  8   WFGM     1449 non-null   int64
#  9   WFGA     1449 non-null   int64
#  10  WFGM3    1449 non-null   int64
#  11  WFGA3    1449 non-null   int64
#  12  WFTM     1449 non-null   int64
#  13  WFTA     1449 non-null   int64
#  14  WOR      1449 non-null   int64
#  15  WDR      1449 non-null   int64
#  16  WAst     1449 non-null   int64
#  17  WTO      1449 non-null   int64
#  18  WStl     1449 non-null   int64
#  19  WBlk     1449 non-null   int64
#  20  WPF      1449 non-null   int64
# ...

# %%
print(f"Length of df: {len(df)}\n")
for col in df.columns:
    print(f"{col}:")
    print(f"nunique: {df[col].nunique()}, min: {df[col].min()}, max: {df[col].max()} \n")
# Out:
# Length of df: 1449
#
# Season:
# nunique: 22, min: 2003, max: 2025
#
# DayNum:
# nunique: 15, min: 134, max: 154
#
# WTeamID:
# nunique: 180, min: 1101, max: 1463
#
# WScore:
# nunique: 64, min: 47, max: 121
#
# LTeamID:
# nunique: 273, min: 1101, max: 1471
#
# LScore:
# nunique: 65, min: 29, max: 105
#
# WLoc:
# nunique: 1, min: N, max: N
#
# NumOT:
# nunique: 3, min: 0, max: 2
#
# WFGM:
# nunique: 30, min: 13, max: 44
#
# WFGA:
# nunique: 46, min: 34, max: 84
#
# WFGM3:
# nunique: 20, min: 0, max: 25
#
# WFGA3:
# nunique: 39, min: 4, max: 51
#
# WFTM:
# nunique: 38, min: 0, max: 38
#
# WFTA:
# nunique: 47, min: 1, max: 48
#
# WOR:
# nunique: 26, min: 0, max: 26
#
# WDR:
# nunique: 31, min: 13, max: 43
#
# WAst:
# nunique: 27, min: 3, max: 29
#
# WTO:
# nunique: 26, min: 2, max: 28
#
# WStl:
# nunique: 18, min: 0, max: 20
#
# WBlk:
# nunique: 15, min: 0, max: 15
#
# WPF:
# nunique: 26, min: 5, max: 30
#
# LFGM:
# nunique: 26, min: 11, max: 36
#
# LFGA:
# ...

# %%
data_length_of_single_season = len(df)/df["Season"].nunique()
data_length_of_single_season
# Out:
# 65.86363636363636

# %% [markdown]
# # Data Section 1

# %% [markdown]
# Completed:
# 1. MTeams.csv & WTeans.csv
# 2. MNCAATourneySeed.csv & WNCAATourneySeed.csv
# 3. MRegularSeasonCompactResults.csv & WRegularSeasonCompactResults.csv
#
#
# UP NEXT: Data Section 1 file: MNCAATourneyCompactResults.csv and WNCAATourneyCompactResults.csv

# %% [markdown]
# ## MNCAATourneyCompactResults.csv
# **Summary**: This dataset contains Season, Matchday, Winner & Looser team ID, their Scores, Match location and Num of extra time. We can find the match stage like Elite Eight, Final Four and Championship with MatchDay.

# %% [markdown]
# # Data Section 2: Team Box Scores

# %% [markdown]
# **Section Description** :
# this section provides game-by-game stats at a team level(free throw attempted, defensive rebounds, turnovers) for all regular season, conference tournament, and NCAA tournament games since the 2003 season(men) and since 2010 season(women).
